# %% [markdown]
# ## Q1: 請問中華郵政6年期儲蓄險『合家歡增額保險』值得買嗎? 年期:6年付費，性別:男，投保年齡:35歲，基本保額:10萬，銀行定存利率1.30%

# %% [markdown]
# ### 算法1, 價如我每年拿同樣的年金去定存，六年後....

# %%
import numpy as np
np.fv(0.013,6,-24844,0,1)
# Out:
# 155995.2896050286

# %% [markdown]
# ### 六年後我可以累積 155,995元....再拿這些錢去多定存四年

# %%
np.fv(0.013,4,0,-155995,1)
# Out:
# 164266.29426943313

# %% [markdown]
# ### 十年後.... 我帳戶會有 164,266元，比郵局的多4,266元，所以單看金額<font color=#FF0000>不划算 > <

# %% [markdown]
# ### 算法2, IRR 內部報酬率計算法

# %%
np.irr([-24844, -24844, -24844, -24844, -24844, -24844, 0, 0, 0, 0, 160000])
# Out:
# 0.009467011246978796

# %% [markdown]
# ### 十年IRR 0.9467% < 1.30%, 所以還是<font color=#FF0000>不划算

# %% [markdown]
# ## Q2:A君中了大樂透，可以選擇每期期初領100 萬元，連領10年期，或者一次領900萬元，假設A君投資理財保守，只與銀行往來定存或活期儲蓄存款，假設預期未來定存年化報酬率為2%，請問A君該選擇一次領還是分期領？

# %%
np.irr([-8000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000])
# Out:
# 0.024227317682617988

# %% [markdown]
# ### 2.4% > 2% , 分10年領比較划算

# %% [markdown]
# ## Q3: 何謂內部報酬率法（Internal Rate of Return, IRR）?決策準則為何?請說明使用IRR 評估投資計畫有那些缺點或限制(請至少寫出3點)

# %% [markdown]
# 1. 內部報酬率法(IRR)是估算NPV=0時，報酬率為多少，以此報酬率和折現值做比較，來評估是不是要進行投資 <br />
# 2. 缺點與限制 <br />
#    a. 投資與借貸的差異, 如果是借貸的話，NPV會有差，所仍需要計算NPV去確認計劃是否可行 <br />
#    b. 多個IRR, 有可能有2個多重解 <br />
#    c. 不存在IRR, 如果以一個計畫根本不存在NPV=0的話，IRR無法計算  <br />

# %% [markdown]
# ## Q4:何謂獲利能力指數（Profitability Index, PI）?決策準則為何?獲利能力指數評估投資計畫的缺點為何?

# %% [markdown]
# 1. 當有預算限制需要決定投資優先順序的時候，單用NPV無法判定，PI可以在有預算限制下做出最佳決策，PI = 第一期開始之現金流量總現值/初期投資<br />
# 2. 缺點 : 當互斥計畫下，會忽略期初投資規模

# %% [markdown]
# ## Q5: 資本預算決策中現金流量的估算是以現金為基礎，為何需考慮折舊費用?

# %% [markdown]
# 因為折舊稅盾關係，折舊會影響到公司應繳稅額，當如果公司稅是20%,折舊1元，應繳稅金降低0.2元，現金流增加0.2元

# %% [markdown]
# ## Q7:一個計劃的現金流量通常包含哪3大來源?

# %% [markdown]
# 1. 資本投入
# 2. 營運資金
# 3. 營運現金收支

# %% [markdown]
# ## Q8:何謂敏感性分析?敏感性分析的優缺點為何?

# %% [markdown]
# 1. 因為投資計畫都有不確定性，敏感性分析為嘗試分析各種狀況的方法<br />
# 2. 優點 : <br />
#     a.檢驗原先估計的NPV是否值得信賴<br />
#     b.提供這個投資計畫該注意的資訊<br />
#    缺點 : <br />
#     a.可能會加深經理人錯誤的想法<br />
#     b.以其他條件固定下的分析<br />

# %% [markdown]
# ## Q9:
# 假設每年銷售 50,000 罐單價為 \$ 4 的草莓果醬，每罐製造成本是 $2.50，新產品
# 通常只有三年壽命。固定成本，包括生產設備的租金，每年須花費 $12,000。必
# 須投資 $90,000 在製造設備上。其將在三年的專案年限內完全折舊完畢，採直
# 線法折舊，到時不具任何價值。公司稅率為34%。專案期初必須投入 $20,000 在
# 淨營運資金上，之後淨營運資金不需再增減。對此產品的投資，要求 20% 的報
# 酬。請計算這投資計畫的淨現值、IRR及幾年還本(計算還本時，不需考慮貨幣
# 時間價值)

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# %%
im = Image.open( "test.jpg" )

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=881x1095 at 0x24A55C40D30>
